# %%
from sklearn.linear_model import LinearRegression

import pandas as pd
import numpy as np

# %%
diabetes_df = pd.read_csv("diabetes.csv")
diabetes_df.head()
# Out:
#    pregnancies  glucose  triceps  insulin   bmi  age  diabetes
# 0            6      148       35        0  33.6   50         1
# 1            1       85       29        0  26.6   31         0
# 2            8      183        0        0  23.3   32         1
# 3            1       89       23       94  28.1   21         0
# 4            0      137       35      168  43.1   33         1

# %%
X = diabetes_df.drop("glucose", axis=1).values
y = diabetes_df["glucose"].values

# %%
from sklearn.model_selection import cross_val_score, KFold

kf = KFold(n_splits=6, shuffle=True, random_state=42)
model =  LinearRegression()
cv_results = cross_val_score(model, X, y, cv=kf)
print(cv_results)
# Out:
# [0.29097927 0.2816585  0.40388857 0.23016064 0.41312863 0.31152736]
